# %% [markdown]
# # Performance of First Generation College Students in STEM Classes
# ## Class data 2015-2019(including summer classes)

# %% [markdown]
# Setups:

# %%
import seaborn as sns
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile
from pathlib import Path

# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,8)
plt.rcParams['figure.dpi'] = 150
sns.set()

# %% [markdown]
# **Data introduction**
#
# The data includes the information about students and related course they have been taken. Only data from 2015 to 2019 is chosen.
#
# Load all the data files needed:

# %%
stem_pathway_2007_2018 = pd.read_csv('firstgen/raw_data_wit/uc.berkeley.stem.pathways.2007.2018.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (32,43,45,50,63,64,65,66,79,80,81,82,83,84,85,86,88,89,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
stem_pathway_2007_2017 = pd.read_csv('firstgen/raw_data_wit/uc.berkeley.stem.pathways.2007.2017.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (33,43,44,50,51,53,55,56,57,58,59,60,61,62,63,64,65,66,67,72,73,74,75,76,77,78,79,80,81,82,83,89,90,92,93,94,95,96,97,98,99,100,101,102,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
class_data_2015 = pd.read_csv('firstgen/raw_data_wit/uc.berkeley.student.course.data.2015.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# Some experimental operations on dataframes above:

# %% [markdown]
# ## First-Gen students indicators
#
# For column `first.generation.college.1` shows the Standard **UCOP** definition of first-generation college:
#
# `Y` stands for "neither parent has earned four-year degree"
#
# `N` stands for "At least one parent has earned four-year degree"
#
# `U` stands for "Not enough information is available to assign Y or N"
#
# For column `first.generation.college.2` shows the non-standard definition of first-generation college used by **OUA**:
#
# `Y` stands for "Neither parent has attended any college"
#
# `N` stands for "At least one parent has attended college"
#
# `U` stands for "Not enough information is available to assign Y or N"

# %%
filtered_pathway_2007_2017 = stem_pathway_2007_2017.loc[:, ('ppsk', 'first.generation.college.1', 'first.generation.college.2')].dropna()
filtered_pathway_2007_2017
# Out:
#           ppsk first.generation.college.1 first.generation.college.2
# 0      1023906                          N                          N
# 1       161295                          N                          N
# 2       183848                          U                          U
# 3       232294                          N                          N
# 4       225526                          N                          N
# ...        ...                        ...                        ...
# 80503  2854707                          N                          N
# 80504  2855617                          N                          N
# 80505  2855618                          N                          N
# 80506  2855940                          Y                          Y
# 80507  2855983                          N                          N
#
# [80422 rows x 3 columns]

# %% [markdown]
# ## Merged 2015 course data(with first-gen information)

# %%
pathway_with_classes_2015 = class_data_2015.merge(filtered_pathway_2007_2017, left_on = 'ppsk', right_on = 'ppsk')

# %% [markdown]
# **2015 Spring analysis:**

# %%
pathway_with_classes_2015_Spring = pathway_with_classes_2015.loc[pathway_with_classes_2015['year.name'] == '2015 Spring']
pathway_with_classes_2015_Spring
# Out:
#           year.name     ppsk undergrad.status         course.department  \
# 0       2015 Spring   331977    Undergraduate                   Physics
# 1       2015 Spring   331977    Undergraduate                   Physics
# 2       2015 Spring   331977    Undergraduate                   Physics
# 5       2015 Spring   331977    Undergraduate                   Physics
# 6       2015 Spring   331977    Undergraduate                   Physics
# ...             ...      ...              ...                       ...
# 403362  2015 Spring   780484         Graduate  South & SE Asian Studies
# 403364  2015 Spring   800386         Graduate            Bioengineering
# 403366  2015 Spring   881632         Graduate                       Law
# 403367  2015 Spring  1486883    Undergraduate                   English
# 403368  2015 Spring  1486883    Undergraduate                   English
#
#                   course.subject course.number      offering.type  \
# 0                        Physics          141B            Primary
# 1                        Physics           250            Primary
# 2                        Physics         H195B  Independent Study
# 5                        Physics           111            Primary
# 6                        Physics          H190            Primary
# ...                          ...           ...                ...
# 403362  South & SE Asian Studies          299B  Independent Study
# 403364            Bioengineering           299  Independent Study
# 403366                       Law          2991  Independent Study
# 403367                   English           80K            Primary
# 403368                   English           199  Independent Study
#
#        section.number    ccn  room.share         course.title  \
# 0                   1  69495       69495  Solid State Physics
# 1                   1  69765       69765       Special Topics
# 2                   6  69567       69567      Thesis Research
# 5                   2  69399       69399   Mod Phys Elect Lab
# 6                   1  69528       69528     Phys Hnrs Course
# ...               ...    ...         ...                  ...
# 403362              1  83461       83461     Dis Prep Rel Res
# 403364             15   7130        7130  Indiv Stud Research
# 403366              1  50978       50978   Harvard Exchange U
# 403367              1  27938       27938       Children'S Lit
# 403368             13  28313       28313   Superv Indep Study
#
#                                           instructor.name  \
# 0                                        Joseph Orenstein
# 1                                          James Analitis
# 2                                          James Analitis
# 5       Arielle Little; Celeste Carruth; Dan Stamper-K...
# 6                                             Kam-Biu Luk
# ...                                                   ...
# 403362                                        George Hart
# 403364                                            Song Li
# 403366                                                NaN
# 403367                                      Joseph Lavery
# 403368                                      Joseph Lavery
#
#               grade.subtype           grade.type grade.name  grade.points  \
# 0                         A         Letter Grade         A+           4.0
# 1                         A         Letter Grade          A           4.0
# 2                         A         Letter Grade         A-           3.7
# 5                         C         Letter Grade          C           2.0
# 6                    Credit     Non-Letter Grade       Pass           NaN
# ...                     ...                  ...        ...           ...
# 403362  Administrative Code  Administrative Code    Unknown           NaN
# 403364  Administrative Code  Administrative Code    Unknown           NaN
# 403366  Administrative Code  Administrative Code    Unknown           NaN
# 403367  Administrative Code  Administrative Code    Unknown           NaN
# 403368  Administrative Code  Administrative Code    Unknown           NaN
#
#         student.credit.hours first.generation.college.1  \
# 0                        3.0                          Y
# 1                        4.0                          Y
# 2                        4.0                          Y
# 5                        3.0                          Y
# 6                        2.0                          Y
# ...                      ...                        ...
# 403362                  12.0                          N
# 403364                  12.0                          Y
# 403366                  12.0                          N
# 403367                   4.0                          Y
# 403368                   2.0                          Y
#
#        first.generation.college.2
# 0                               Y
# 1                               Y
# 2                               Y
# 5                               Y
# 6                               Y
# ...                           ...
# 403362                          N
# 403364                          N
# 403366                          N
# 403367                          Y
# 403368                          Y
#
# [182637 rows x 19 columns]

# %% [markdown]
# ## CS 61A:

# %%
cs_61a = pathway_with_classes_2015_Spring.loc[pathway_with_classes_2015_Spring['course.title'] == 'Str Interp Cmp Prgs']
cs_61a_letter = cs_61a.loc[cs_61a['grade.type'] == 'Letter Grade']
cs_61a_letter_status = cs_61a_letter.loc[cs_61a_letter['first.generation.college.1'].isin(['Y', 'N'])]
cs_61a_by_type_status = cs_61a_letter_status.groupby(['first.generation.college.1', 'grade.subtype']).agg({'grade.subtype': 'count'})
cs_61a_by_type_status = cs_61a_by_type_status.rename(columns = {'grade.subtype': 'Count'})

# %%
non_first_gen_student_61a = cs_61a_letter_status.groupby('first.generation.college.1').count().iloc[0, 0]
first_gen_student_61a = cs_61a_letter_status.groupby('first.generation.college.1').count().iloc[1, 0]

non_first_gen_student_perc_61a = pd.DataFrame((np.round(cs_61a_by_type_status.loc[('N')]/non_first_gen_student *100)).iloc[:,0])
first_gen_student_perc_61a = pd.DataFrame((np.round(cs_61a_by_type_status.loc[('Y')]/first_gen_student * 100)).iloc[:,0])

# %%
agg_data_61a = non_first_gen_student_perc_61a.copy()
agg_data_61a = agg_data_61a.rename(columns={'Count': 'Non First-Gen %'})

# %%
agg_data_61a['First-Gen %'] = first_gen_student_perc_61a.loc[:, 'Count']
agg_data_61a
# Out:
#                Non First-Gen %  First-Gen %
# grade.subtype
# A                         37.0         24.0
# B                         51.0         50.0
# C                          8.0         20.0
# D                          1.0          4.0
# F                          3.0          2.0

# %%
agg_data_61a.plot.bar(rot=0)
plt.title('The grade distribution of First-Gen/Non First-Gen College Student for CS61A')
plt.xlabel('grade categories')
plt.ylabel('percentage of grade distribution');

# %% [markdown]
# ## CS 61B:

# %%
cs_61b = pathway_with_classes_2015_Spring.loc[pathway_with_classes_2015_Spring['course.title'] == 'Data Structures']
cs_61b_letter = cs_61b.loc[cs_61b['grade.type'] == 'Letter Grade']
cs_61b_letter_status = cs_61b_letter.loc[cs_61b_letter['first.generation.college.1'].isin(['Y', 'N'])]
cs_61b_by_type_status = cs_61b_letter_status.groupby(['first.generation.college.1', 'grade.subtype']).agg({'grade.subtype': 'count'})
cs_61b_by_type_status = cs_61b_by_type_status.rename(columns = {'grade.subtype': 'Count'})

# %%
non_first_gen_student_61b = cs_61b_letter_status.groupby('first.generation.college.1').count().iloc[0, 0]
first_gen_student_61b = cs_61b_letter_status.groupby('first.generation.college.1').count().iloc[1, 0]

non_first_gen_student_perc_61b = pd.DataFrame((np.round(cs_61b_by_type_status.loc[('N')]/non_first_gen_student_61b * 100)).iloc[:,0])
first_gen_student_perc_61b = pd.DataFrame((np.round(cs_61b_by_type_status.loc[('Y')]/first_gen_student_61b * 100)).iloc[:,0])

# %%
agg_data_61b = non_first_gen_student_perc_61b.copy()
agg_data_61b = agg_data_61b.rename(columns={'Count': 'Non First-Gen %'})
agg_data_61b['First-Gen %'] = first_gen_student_perc_61b.loc[:, 'Count']

# %%
agg_data_61b.plot.bar(rot=0)
plt.title('The grade distribution of First-Gen/Non First-Gen College Student for CS61B')
plt.xlabel('grade categories')
plt.ylabel('percentage of grade distribution');

# %% [markdown]
# ## CS 70:

# %%
cs_70 = pathway_with_classes_2015_Spring.loc[pathway_with_classes_2015_Spring['course.title'] == 'Discrete Math&Prob']
cs_70_letter = cs_70.loc[cs_70['grade.type'] == 'Letter Grade']
cs_70_letter_status = cs_70_letter.loc[cs_70_letter['first.generation.college.1'].isin(['Y', 'N'])]
cs_70_by_type_status = cs_70_letter_status.groupby(['first.generation.college.1', 'grade.subtype']).agg({'grade.subtype': 'count'})
cs_70_by_type_status = cs_70_by_type_status.rename(columns = {'grade.subtype': 'Count'})

# %%
non_first_gen_student_70 = cs_70_letter_status.groupby('first.generation.college.1').count().iloc[0, 0]
first_gen_student_70 = cs_70_letter_status.groupby('first.generation.college.1').count().iloc[1, 0]

non_first_gen_student_perc_70 = pd.DataFrame((np.round(cs_70_by_type_status.loc[('N')]/non_first_gen_student_70 * 100)).iloc[:,0])
first_gen_student_perc_70 = pd.DataFrame((np.round(cs_70_by_type_status.loc[('Y')]/first_gen_student_70 * 100)).iloc[:,0])

# %%
agg_data_70 = non_first_gen_student_perc_70.copy()
agg_data_70 = agg_data_70.rename(columns={'Count': 'Non First-Gen %'})
agg_data_70['First-Gen %'] = first_gen_student_perc_70.loc[:, 'Count']

# %%
agg_data_70.plot.bar(rot=0)
plt.title('The grade distribution of First-Gen/Non First-Gen College Student for CS70')
plt.xlabel('grade categories')
plt.ylabel('percentage of grade distribution');

# %% [markdown]
# **2015 Fall analysis:**

# %%
pathway_with_classes_2015_Fall = pathway_with_classes_2015.loc[pathway_with_classes_2015['year.name'] == '2015 Fall']
pathway_with_classes_2015_Fall
# Out:
#         year.name     ppsk undergrad.status            course.department  \
# 3       2015 Fall   331977         Graduate                      Physics
# 4       2015 Fall   331977         Graduate                      Physics
# 7       2015 Fall   331977         Graduate                      Physics
# 8       2015 Fall   331977         Graduate                      Physics
# 12      2015 Fall   331977         Graduate                      Physics
# ...           ...      ...              ...                          ...
# 408216  2015 Fall  2641644    Undergraduate  FPF-Gender & Womens Studies
# 408217  2015 Fall  2641644    Undergraduate     FPF-IAS Teaching Program
# 408218  2015 Fall  2641644    Undergraduate      FPF-Integrative Biology
# 408219  2015 Fall  2641644    Undergraduate        FPF-Political Science
# 408220  2015 Fall  2641644    Undergraduate        FPF-Political Science
#
#                   course.subject course.number      offering.type  \
# 3                        Physics          240A            Primary
# 4                        Physics           209            Primary
# 7                        Physics           301  Independent Study
# 8                        Physics           375            Primary
# 12                       Physics           209          Secondary
# ...                          ...           ...                ...
# 408216  FPF-Gender & Womens Stds            10          Secondary
# 408217   FPF-Middle Eastern Stds            10            Primary
# 408218   FPF-Integrative Biology            33            Primary
# 408219     FPF-Political Science             2            Primary
# 408220     FPF-Political Science             2          Secondary
#
#        section.number    ccn  room.share         course.title  \
# 3                   1  69723       69723  Quantum Theo Solids
# 4                   1  69660       69660     Electromagnetism
# 7                   1  70173       70173   Adv Prof Prep Phys
# 8                   1  70176       70176    Prof Prep Of Phys
# 12                102  69666       69666     Electromagnetism
# ...               ...    ...         ...                  ...
# 408216            102  91109       91109  Int Gender/Wom Stdy
# 408217              1  91903       91903    Intro Middle East
# 408218              1  91403       91403   Ecol Evol Of Dinos
# 408219              1  92303       92303   Intro Comparat Pol
# 408220            101  92306       92306   Intro Comparat Pol
#
#             instructor.name        grade.subtype           grade.type  \
# 3              Steven Louie                    B         Letter Grade
# 4              Martin White                    B         Letter Grade
# 7          Marjorie Shapiro               Credit     Non-Letter Grade
# 8            Benjamin Spike               Credit     Non-Letter Grade
# 12               Eugene Kur  Administrative Code  Administrative Code
# ...                     ...                  ...                  ...
# 408216        Laura Fantone  Administrative Code  Administrative Code
# 408217  Mahmood Monshipouri  Administrative Code  Administrative Code
# 408218      Bonnie Rauscher  Administrative Code  Administrative Code
# 408219          Wendy Sinek  Administrative Code  Administrative Code
# 408220          Wendy Sinek  Administrative Code  Administrative Code
#
#           grade.name  grade.points  student.credit.hours  \
# 3                 B+           3.3                   4.0
# 4                 B-           2.7                   5.0
# 7       Satisfactory           NaN                   2.0
# 8       Satisfactory           NaN                   2.0
# 12           Unknown           NaN                   NaN
# ...              ...           ...                   ...
# 408216       Unknown           NaN                   NaN
# 408217       Unknown           NaN                   4.0
# 408218       Unknown           NaN                   3.0
# 408219       Unknown           NaN                   4.0
# 408220       Unknown           NaN                   NaN
#
#        first.generation.college.1 first.generation.college.2
# 3                               Y                          Y
# 4                               Y                          Y
# 7                               Y                          Y
# 8                               Y                          Y
# 12                              Y                          Y
# ...                           ...                        ...
# 408216                          Y                          Y
# 408217                          Y                          Y
# 408218                          Y                          Y
# 408219                          Y                          Y
# 408220                          Y                          Y
#
# [198938 rows x 19 columns]
